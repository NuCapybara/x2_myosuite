# %% [markdown]
# # 2024 NeurIPS - MyoChallenge
#
# ## <center> Welcome to the [**2024 NeurIPS - MyoChallenge:  Physiological Dexterity and Agility in Enhanced Humans**](https://sites.google.com/view/myosuite/myochallenge/myochallenge-2024) </center>

# %% [markdown]
# # 1. Setting the environment

# %%
# !pip install myosuite==2.5.0
# !pip install stable-baselines3[extra]  --quiet
# !pip install tqdm  --quiet
# !pip install sk-video
# %env MUJOCO_GL=egl
import mujoco
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: myosuite==2.5.0 in /home/jialuyu/.local/lib/python3.10/site-packages (2.5.0)
# Requirement already satisfied: click in /home/jialuyu/.local/lib/python3.10/site-packages (from myosuite==2.5.0) (8.1.7)
# Requirement already satisfied: sk-video in /home/jialuyu/.local/lib/python3.10/site-packages (from myosuite==2.5.0) (1.1.10)
# Requirement already satisfied: gymnasium==0.29.1 in /home/jialuyu/.local/lib/python3.10/site-packages (from myosuite==2.5.0) (0.29.1)
# Requirement already satisfied: termcolor in /home/jialuyu/.local/lib/python3.10/site-packages (from myosuite==2.5.0) (2.4.0)
# Requirement already satisfied: flatten-dict in /home/jialuyu/.local/lib/python3.10/site-packages (from myosuite==2.5.0) (0.4.2)
# Requirement already satisfied: h5py in /home/jialuyu/.local/lib/python3.10/site-packages (from myosuite==2.5.0) (3.11.0)
# Requirement already satisfied: numpy in /home/jialuyu/.local/lib/python3.10/site-packages (from myosuite==2.5.0) (1.24.3)
# Requirement already satisfied: mujoco==3.1.2 in /home/jialuyu/.local/lib/python3.10/site-packages (from myosuite==2.5.0) (3.1.2)
# Requirement already satisfied: dm-control==1.0.16 in /home/jialuyu/.local/lib/python3.10/site-packages (from myosuite==2.5.0) (1.0.16)
# Requirement already satisfied: Pillow in /home/jialuyu/.local/lib/python3.10/site-packages (from myosuite==2.5.0) (10.4.0)
# Requirement already satisfied: pink-noise-rl in /home/jialuyu/.local/lib/python3.10/site-packages (from myosuite==2.5.0) (2.0.1)
# Requirement already satisfied: packaging in /home/jialuyu/.local/lib/python3.10/site-packages (from myosuite==2.5.0) (24.1)
# Requirement already satisfied: gitpython in /home/jialuyu/.local/lib/python3.10/site-packages (from myosuite==2.5.0) (3.1.43)
# Requirement already satisfied: absl-py>=0.7.0 in /home/jialuyu/.local/lib/python3.10/site-packages (from dm-control==1.0.16->myosuite==2.5.0) (2.1.0)
# Requirement already satisfied: dm-env in /home/jialuyu/.local/lib/python3.10/site-packages (from dm-control==1.0.16->myosuite==2.5.0) (1.6)
# Requirement already satisfied: dm-tree!=0.1.2 in /home/jialuyu/.local/lib/python3.10/site-packages (from dm-control==1.0.16->myosuite==2.5.0) (0.1.8)
# Requirement already satisfied: glfw in /home/jialuyu/.local/lib/python3.10/site-packages (from dm-control==1.0.16->myosuite==2.5.0) (2.7.0)
# Requirement already satisfied: labmaze in /home/jialuyu/.local/lib/python3.10/site-packages (from dm-control==1.0.16->myosuite==2.5.0) (1.0.6)
# Requirement already satisfied: lxml in /home/jialuyu/.local/lib/python3.10/site-packages (from dm-control==1.0.16->myosuite==2.5.0) (5.3.0)
# Requirement already satisfied: protobuf>=3.19.4 in /home/jialuyu/.local/lib/python3.10/site-packages (from dm-control==1.0.16->myosuite==2.5.0) (3.19.5)
# Requirement already satisfied: pyopengl>=3.1.4 in /home/jialuyu/.local/lib/python3.10/site-packages (from dm-control==1.0.16->myosuite==2.5.0) (3.1.7)
# Requirement already satisfied: pyparsing>=3.0.0 in /home/jialuyu/.local/lib/python3.10/site-packages (from dm-control==1.0.16->myosuite==2.5.0) (3.1.2)
# Requirement already satisfied: requests in /home/jialuyu/.local/lib/python3.10/site-packages (from dm-control==1.0.16->myosuite==2.5.0) (2.31.0)
# Requirement already satisfied: setuptools!=50.0.0 in /home/jialuyu/.local/lib/python3.10/site-packages (from dm-control==1.0.16->myosuite==2.5.0) (58.2.0)
# Requirement already satisfied: scipy in /home/jialuyu/.local/lib/python3.10/site-packages (from dm-control==1.0.16->myosuite==2.5.0) (1.14.1)
# Requirement already satisfied: tqdm in /home/jialuyu/.local/lib/python3.10/site-packages (from dm-control==1.0.16->myosuite==2.5.0) (4.66.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/jialuyu/.local/lib/python3.10/site-packages (from gymnasium==0.29.1->myosuite==2.5.0) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/jialuyu/.local/lib/python3.10/site-packages (from gymnasium==0.29.1->myosuite==2.5.0) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/jialuyu/.local/lib/python3.10/site-packages (from gymnasium==0.29.1->myosuite==2.5.0) (0.0.4)
# Requirement already satisfied: etils[epath] in /home/jialuyu/.local/lib/python3.10/site-packages (from mujoco==3.1.2->myosuite==2.5.0) (1.7.0)
# Requirement already satisfied: six<2.0,>=1.12 in /home/jialuyu/.local/lib/python3.10/site-packages (from flatten-dict->myosuite==2.5.0) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/jialuyu/.local/lib/python3.10/site-packages (from gitpython->myosuite==2.5.0) (4.0.11)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/jialuyu/.local/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython->myosuite==2.5.0) (5.0.1)
# Requirement already satisfied: fsspec in /home/jialuyu/.local/lib/python3.10/site-packages (from etils[epath]->mujoco==3.1.2->myosuite==2.5.0) (2024.6.0)
# Requirement already satisfied: importlib_resources in /home/jialuyu/.local/lib/python3.10/site-packages (from etils[epath]->mujoco==3.1.2->myosuite==2.5.0) (6.4.0)
# Requirement already satisfied: zipp in /home/jialuyu/.local/lib/python3.10/site-packages (from etils[epath]->mujoco==3.1.2->myosuite==2.5.0) (3.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jialuyu/.local/lib/python3.10/site-packages (from requests->dm-control==1.0.16->myosuite==2.5.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/jialuyu/.local/lib/python3.10/site-packages (from requests->dm-control==1.0.16->myosuite==2.5.0) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jialuyu/.local/lib/python3.10/site-packages (from requests->dm-control==1.0.16->myosuite==2.5.0) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jialuyu/.local/lib/python3.10/site-packages (from requests->dm-control==1.0.16->myosuite==2.5.0) (2024.8.30)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-api-core 2.14.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5, but you have protobuf 5.28.0 which is incompatible.
# google-cloud-speech 2.22.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.28.0 which is incompatible.
# googleapis-common-protos 1.61.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5, but you have protobuf 5.28.0 which is incompatible.
# proto-plus 1.22.3 requires protobuf<5.0.0dev,>=3.19.0, but you have protobuf 5.28.0 which is incompatible.
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sk-video in /home/jialuyu/.local/lib/python3.10/site-packages (1.1.10)
# Requirement already satisfied: numpy in /home/jialuyu/.local/lib/python3.10/site-packages (from sk-video) (1.24.3)
# Requirement already satisfied: scipy in /home/jialuyu/.local/lib/python3.10/site-packages (from sk-video) (1.14.1)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# env: MUJOCO_GL=egl

# %% [markdown]
# ### Define a method to show the rendering inside the Colab

# %%
from IPython.display import HTML
from base64 import b64encode

def show_video(video_path, video_width = 400):

  video_file = open(video_path, "r+b").read()

  video_url = f"data:video/mp4;base64,{b64encode(video_file).decode()}"
  return HTML(f"""<video autoplay width={video_width} controls><source src="{video_url}"></video>""")

# %% [markdown]
# ### All the `MyoSuite` imports needed to run this tutorial

# %%
import myosuite
from myosuite.utils import gym
import skvideo.io
import numpy as np
import os
from stable_baselines3 import PPO
from tqdm import tqdm_notebook as tqdm
# Out:
# /home/jialuyu/.local/lib/python3.10/site-packages/pygame/pkgdata.py:25: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import resource_stream, resource_exists
# /home/jialuyu/.local/lib/python3.10/site-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /home/jialuyu/.local/lib/python3.10/site-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /home/jialuyu/.local/lib/python3.10/site-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /home/jialuyu/.local/lib/python3.10/site-packages/pkg_resources/__init__.py:2563: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(parent)
# /home/jialuyu/.local/lib/python3.10/site-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /home/jialuyu/.local/lib/python3.10/site-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.logging')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /home/jialuyu/.local/lib/python3.10/site-packages/pkg_resources/__init__.py:2563: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(parent)
# /home/jialuyu/.local/lib/python3.10/site-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('mpl_toolkits')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# pygame 2.6.0 (SDL 2.28.4, Python 3.10.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# MyoSuite:> Registering Myo Envs

# %% [markdown]
# ## Creating the MyoChallenge '24 Environment and train your model
#
# ### Loading the Locomotion Challenge Env
#
# As a basic example, we use PPO to train the locomotion environment on a task to walk over different types of terrain. Some helper functions are also provided for the environment initialization, so feel free to explore them.

# %%
# Create the MyoChallenge environment and train the model with PPO

"""
Preset environment modes are as given as ['init', 'random', 'osl_init']:
These can be activated by passing an argument "reset_type"

1. init - Resets the model in a neutral standing pose. OSL State Machine is initialized with 'e_stance'

2. random - Resets the model in a random pose. OSL State Machine initialized with 'e_stance'.
IMPT: State Machine not guranteed to be stable, since there joint positions do not match the thresholds in the state transitions.

3. osl_init - Resets the model with a pose sampled from a sample gait trajectory.
IMPT: State Machine initialized according to the pose sampled. Sampled poses are within state transition thresholds. More stable than "random"
"""

env = gym.make('myoChallengeRunTrackP1-v0', reset_type='init')

model = PPO("MlpPolicy", env, verbose=0)
model.learn(total_timesteps=100)
# Out:
#     MyoSuite: A contact-rich simulation suite for musculoskeletal motor control
#         Vittorio Caggiano, Huawei Wang, Guillaume Durandau, Massimo Sartori, Vikash Kumar
#         L4DC-2019 | https://sites.google.com/view/myosuite
# /home/jialuyu/.local/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:159: UserWarning: WARN: The obs returned by the `reset()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# /home/jialuyu/.local/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:159: UserWarning: WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")

# %%
# evaluate policy
all_rewards = []
for _ in tqdm(range(5)): # Randomization over different terrain types
  ep_rewards = []
  done = False
  obs = env.reset()
  while not done:
      obs = env.obsdict2obsvec(env.obs_dict, env.obs_keys)[1]
      # get the next action from the policy
      action, _ = model.predict(obs, deterministic=True)
      # take an action based on the current observation
      obs, reward, done, info, _ = env.step(action)
      ep_rewards.append(reward)
  all_rewards.append(np.sum(ep_rewards))
print(f"Average reward: {np.mean(all_rewards)} over 20 episodes")
# Out:
# /tmp/ipykernel_7513/1272391537.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for _ in tqdm(range(5)): # Randomization over different terrain types
#   0%|          | 0/5 [00:00<?, ?it/s]
# /home/jialuyu/.local/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.obsdict2obsvec to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.obsdict2obsvec` for environment variables or `env.get_wrapper_attr('obsdict2obsvec')` that will search the reminding wrappers.
#   logger.warn(
# /home/jialuyu/.local/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.obs_dict to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.obs_dict` for environment variables or `env.get_wrapper_attr('obs_dict')` that will search the reminding wrappers.
#   logger.warn(
# /home/jialuyu/.local/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.obs_keys to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.obs_keys` for environment variables or `env.get_wrapper_attr('obs_keys')` that will search the reminding wrappers.
#   logger.warn(
# Average reward: 3.5469735733090557 over 20 episodes

# %% [markdown]
# ## Rendering your policy
#
# You can render your policy on the task with the built-in renderer below.

# %%
# Render trained policy
frames = []
for _ in tqdm(range(5)): # Randomization over different terrain types
  env.reset()
  ep_rewards = []
  done = False
  obs = env.reset()
  for _ in range(20):
      obs = env.obsdict2obsvec(env.obs_dict, env.obs_keys)[1]
      # get the next action from the policy
      action, _ = model.predict(obs, deterministic=True)
      geom_1_indices = np.where(env.sim.model.geom_group == 1)
      env.sim.model.geom_rgba[geom_1_indices, 3] = 0
      frame = env.sim.renderer.render_offscreen(
                        width=400,
                        height=400,
                        camera_id=1)
      frames.append(frame)
      # take an action based on the current observation
      obs, reward, done, info, _ = env.step(action)

env.close()

os.makedirs('videos', exist_ok=True)
# make a local copy
skvideo.io.vwrite('videos/test_policy.mp4', np.asarray(frames),outputdict={"-pix_fmt": "yuv420p"})
show_video('videos/test_policy.mp4')
# Out:
# /tmp/ipykernel_7513/1271687860.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for _ in tqdm(range(5)): # Randomization over different terrain types
#   0%|          | 0/5 [00:00<?, ?it/s]
# /home/jialuyu/.local/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.sim to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.sim` for environment variables or `env.get_wrapper_attr('sim')` that will search the reminding wrappers.
#   logger.warn(
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# /home/jialuyu/.local/lib/python3.10/site-packages/skvideo/io/ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# <video autoplay width=400 controls><source src="data:video/mp4;base64,..."></video>
